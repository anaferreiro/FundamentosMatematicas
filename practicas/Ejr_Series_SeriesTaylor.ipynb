# %% [markdown]
# - Serie
# $$
# \displaystyle \sum \frac{(-1)^n}{(2n)!}
# $$
# Es una serie convergente

# %%
import math
n=20
suma=0
for k in range(0,n):
    suma+= (-1)**k /math.factorial(2.*k)

print("Valor de convergencia= ", suma)
# Out:
# Valor de convergencia=  0.5403023058681397

# %% [markdown]
# - Ejr 6: Determinar la serie de McLaurin y su radio de convergencia para la función
# $$
# \displaystyle f(x)= \frac{1}{(1-x)^2}
# $$

# %%
# %matplotlib inline
import sympy as sp
x=sp.symbols('x')
f=1./(1-x)**2
fig=sp.plot(f,show=False, line_color='blue',xlim=(-1,0.5),ylim=(-0.1,2))
color=['red','green', 'gray', 'pink']
i=1
for k in range(3,20,4):
    pk=sp.series(f,x,0,k)
    pk=pk.removeO()
    figk=sp.plot(pk,show=False,line_color = f'C{i}')
    fig.extend(figk)
    i+=1
fig.show()

# %% [markdown]
# Ejr 8: Calcular la serie de McLaurin asociada a la función
# $$
# \displaystyle f(x) = \frac{1}{4-2x}
# $$

# %%
# %matplotlib inline
import sympy as sp
x=sp.symbols('x')
f=1./(4-2*x)
fig=sp.plot(f,show=False, line_color='blue',xlim=(-0.5,0.5),ylim=(0.2,0.3))
color=['red','green', 'gray', 'pink']
i=1
for k in range(3,6):
    pk=sp.series(f,x,0,k)
    pk=pk.removeO()
    figk=sp.plot(pk,show=False,line_color = f'C{i}')
    fig.extend(figk)
    i+=1
fig.show()

# %% [markdown]
# Ejr 8: Calcular la serie de Taylor centrada en $x_0=1$ asociada a la función
# $$
# \displaystyle f(x) = \frac{1}{x}
# $$

# %%
# %matplotlib inline
import sympy as sp
x=sp.symbols('x')
f=1./(4-2*x)
fig=sp.plot(f,show=False, line_color='blue',xlim=(0.5,1.5),ylim=(0.3,1.1))
x0=1
i=1
for k in range(3,10,4):
    pk=sp.series(f,x,x0,k)
    pk=pk.removeO()
    figk=sp.plot(pk,show=False,line_color = f'C{i}')
    fig.extend(figk)
    i+=1
fig.show()
